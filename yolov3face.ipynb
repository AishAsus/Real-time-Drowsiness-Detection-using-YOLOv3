# %% [markdown]
# Usage example:  python yoloface.py --image samples/outside_000001.jpg \<br>
#                                    --output-dir outputs/<br>
#                 python yoloface.py --video samples/subway.mp4 \<br>
#                                    --output-dir outputs/<br>
#                 python yoloface.py --src 1 --output-dir outputs/

# %%
from google.colab import drive
drive.mount("/content/drive",force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#import argparse
import sys
import os
import cv2
sys.path.insert(0, "/content/drive/My Drive/yolov3/yolo/yoloface")

# %%
from utils import *
from python_utils import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f2335606557d> in <module>()
# ----> 1 from utils import *
#       2 from python_utils import *
#
# ModuleNotFoundError: No module named 'utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ###################################################################

# %%
'''
parser = argparse.ArgumentParser()
parser.add_argument('--model-cfg', type=str, default='./cfg/yolov3-face.cfg',
                    help='path to config file')
parser.add_argument('--model-weights', type=str,
                    default='./model-weights/yolov3-wider_16000.weights',
                    help='path to weights of model')
parser.add_argument('--image', type=str, default='',
                    help='path to image file')
parser.add_argument('--video', type=str, default='',
                    help='path to video file')
parser.add_argument('--src', type=int, default=0,
                    help='source of the camera')
parser.add_argument('--output-dir', type=str, default='outputs/',
                    help='path to the output directory')
args = parser.parse_args()
'''
model_cfg = '/content/drive/My Drive/yolov3/yolo/yoloface/yolo/cfg/yolov3-face.cfg'
model_weights = '/content/drive/My Drive/yolov3/yolo/yoloface/yolo/model-weights/yolov3-wider_16000.weights'
#image = '/content/drive/My Drive/Colab Notebooks/drowsiness_detect/yoloface/samples/outside_000001.jpg'
image = ''
#video = '/content/drive/My Drive/Colab Notebooks/data/Test/003_nightnoglasses_mix.mp4'Copy of 003_glasses_mix.mp4
#video = '/content/drive/My Drive/Colab Notebooks/drowsiness_detect/yoloface/samples/subway.mp4'
video = '/content/drive/My Drive/yolov3/yolo/yoloface/samples/dro.mp4'
output_dir = '/content/drive/My Drive/yolov3/yolo/yoloface/outputcolab/Drowsy1'

# %% [markdown]
# ###################################################################<br>
# print the arguments

# %%
print('----- info -----')
print('[i] The config file: ', model_cfg)
print('[i] The weights of model file: ', model_weights)
print('[i] Path to image file: ', image)
print('[i] Path to video file: ', video)
print('###########################################################\n')
# Out:
# ----- info -----
# [i] The config file:  /content/drive/My Drive/yoloface/yolo/cfg/yolov3-face.cfg
# [i] The weights of model file:  /content/drive/My Drive/yoloface/yolo/model-weights/yolov3-wider_16000.weights
# [i] Path to image file:
# [i] Path to video file:  /content/drive/My Drive/yoloface/samples/adro.mp4
# ###########################################################

# %%
# !ls '/content/drive/My Drive/yolov3/yolo/yoloface/samples/'
# Out:
# ls: cannot access '/content/drive/My Drive/yolov3/yolo/yoloface/samples/': No such file or directory

# %% [markdown]
# check outputs directory

# %%
'''
if not os.path.exists(args.output_dir):
    print('==> Creating the {} directory...'.format(args.output_dir))
else:
    print('==> Skipping create the {} directory...'.format(args.output_dir))

'''
# Out:
# "\nif not os.path.exists(args.output_dir):\n    print('==> Creating the {} directory...'.format(args.output_dir))\n    os.makedirs(args.output_dir)\nelse:\n    print('==> Skipping create the {} directory...'.format(args.output_dir))\n\n"

# %% [markdown]
# Give the configuration and weight files for the model and load the network<br>
# using them.

# %%
net = cv2.dnn.readNetFromDarknet(model_cfg, model_weights)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

# %%
import numpy as np
#def _main():
#wind_name = 'face detection using YOLOv3'
#cv2.namedWindow(wind_name, cv2.WINDOW_NORMAL)
output_file = ''
#if args.image:
if image:
    #if not os.path.isfile(args.image):
    if not os.path.isfile(image):
        #print("[!] ==> Input image file {} doesn't exist".format(args.image))
        print("[!] ==> Input image file {} doesn't exist".format(image))
        sys.exit(1)
    #cap = cv2.VideoCapture(args.image)
    cap = cv2.VideoCapture(image)
    #output_file = args.image[:-4].rsplit('/')[-1] + '_yoloface.jpg'
    output_file = image[:-4].rsplit('/')[-1] + '_yoloface.jpg'

    #elif args.video:
elif video:
    #if not os.path.isfile(args.video):
    if not os.path.isfile(video):
        #print("[!] ==> Input video file {} doesn't exist".format(args.video))
        print("[!] ==> Input video file {} doesn't exist".format(video))
        sys.exit(1)
    #cap = cv2.VideoCapture(args.video)
    cap = cv2.VideoCapture(video)
    #output_file = args.video[:-4].rsplit('/')[-1] + '_yoloface.avi'
    output_file = video[:-4].rsplit('/')[-1] + '_yoloface.avi'

'''
else:
    # Get data from the camera
    cap = cv2.VideoCapture(args.src)
	###############
    output_file = 'webcam_yoloface.avi'
###################
'''
# Get the video writer initialized to save the output video
#if not args.image:
if not image:
    video_writer = cv2.VideoWriter(os.path.join(output_dir, output_file),
                                       cv2.VideoWriter_fourcc('M', 'J', 'P', 'G'),
                                       cap.get(cv2.CAP_PROP_FPS), (
                                           round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
                                           round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))
cpt=0
if True:
    while True:
        has_frame, frame = cap.read()

        # Stop the program if reached end of video
        if not has_frame:
            print('[i] ==> Done processing!!!')
            #print('[i] ==> Output file is stored at', os.path.join(args.output_dir, output_file))
            print('[i] ==> Output file is stored at', os.path.join(output_dir, output_file))
            #cv2.waitKey(1000)
            break

        # Create a 4D blob from a frame.
        blob = cv2.dnn.blobFromImage(frame, 1 / 255, (IMG_WIDTH, IMG_HEIGHT),
                                     [0, 0, 0], 1, crop=False)

        # Sets the input to the network
        net.setInput(blob)

        # Runs the forward pass to get output of the output layers
        outs = net.forward(get_outputs_names(net))

        # Remove the bounding boxes with low confidence
        faces, crop_frame = post_process(frame, outs, CONF_THRESHOLD, NMS_THRESHOLD)
        #print(faces)
        #print(crop_frame)
        #print(np.shape(crop_frame[0]))
        #print(crop_frame[0])
        print('[i] ==> # detected faces: {}'.format(len(faces)))
        print('#' * 60)

        # initialize the set of information we'll displaying on the frame
        info = [
            ('number of faces detected', '{}'.format(len(faces)))
        ]
        for (i, (txt, val)) in enumerate(info):
            text = '{}: {}'.format(txt, val)
            cv2.putText(frame, text, (10, (i * 20) + 20),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, COLOR_RED, 2)
            
            

        #for i in range()
        for i in range(np.shape(crop_frame)[0]):

          # Save the output video to file
          #if args.image:
          if image:
              #cv2.imwrite(os.path.join(args.output_dir, output_file), frame.astype(np.uint8))
              cv2.imwrite(os.path.join(output_dir, output_file), frame.astype(np.uint8))
            
          else:
              video_writer.write(frame.astype(np.uint8))
              cv2.imwrite('/content/drive/My Drive/yolov3/yolo/yoloface/outputcolab/Drowsy1/img%04i_%i.jpg' %(cpt, i), crop_frame[i])
          #cv2.imshow(wind_name, frame)
          #key = cv2.waitKey(1)
          #if key == 27 or key == ord('q'):
          #    print('[i] ==> Interrupted by user!')
          #    break
        cpt +=1      
    cap.release()
    #cv2.destroyAllWindows()

print('==> All done!')
print('***********************************************************')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-24298c0e5065> in <module>()
#      67
#      68         # Runs the forward pass to get output of the output layers
# ---> 69         outs = net.forward(get_outputs_names(net))
#      70
#      71         # Remove the bounding boxes with low confidence
#
# NameError: name 'get_outputs_names' is not defined

# %%
'''
if __name__ == '__main__':
    _main()
    '''
